# %% [markdown]
# <a href="https://colab.research.google.com/github/agustinaceliaolmos-boop/Gesti-n-Colaborativa-OE/blob/main/Gesti_n_Colaborativa_OE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Captura de pantalla 2026-05-24 133619.png](data:image/png;base64,...)
# Trabajo Práctico 2:"Gestión Colaborativa, Control de Versiones y Organización Empresarial"

# %% [markdown]
# Alumnos - Grupo n° XX
#
# OLMOS AGUSTINA CELIA
#
# Tecnicatura Universitaria en Programación - Universidad Tecnológica Nacional.
# Organización Empresarial
#
# Docente Tutor
#
# Mónica Mut
#
# 17 de mayo de 2026

# %% [markdown]
# **Tabla de contenido**
#
#
# 1.   Introduccion
# 2.   Desarrollo
#
#
# *   Consigna 1
# *   Consigna 2
#
#
# 3.   Conclusion
# 4.   Referencias

# %% [markdown]
# **1. INTRODUCCIÓN**
#
#
# En el desarrollo de software y en los procesos de análisis de datos, la correcta organización del trabajo, el control de versiones y la trazabilidad de las tareas resultan fundamentales para garantizar calidad, reproducibilidad y transparencia. Herramientas como Git, GitHub y Jira permiten integrar la gestión empresarial con la implementación técnica, facilitando el trabajo colaborativo y el seguimiento de cambios.
#
# El presente Trabajo Práctico se desarrolla bajo el enfoque de Aprendizaje Basado en Problemas (ABP), integrando conceptos de organización empresarial con prácticas profesionales de ingeniería de software. Aunque el escenario simula una célula de desarrollo, el trabajo es realizado de forma individual, asumiendo todos los roles definidos en la consigna.

# %% [markdown]
# ***OBJETIVOS***
#
# *   Comprender la importancia del control de versiones en proyectos profesionales.
# *   Aplicar un flujo de trabajo con Git y GitHub desde Google Colab.
# *   Utilizar Jira como herramienta de planificación y trazabilidad.
# *   Implementar un análisis de ventas mediante scripts reproducibles en Python.
# *   Documentar el proyecto siguiendo buenas prácticas profesionales.
# *   Garantizar seguridad en la gestión de credenciales y datos.

# %% [markdown]
# **2. DESARROLLO**
#
# ESCENARIO DEL PROYECTO: ANÁLISIS DE VENTAS
#
# Escenario B – Análisis de Ventas de una Pequeña Empresa
#
# Objetivo
#
# Analizar un conjunto de datos de ventas simuladas para generar indicadores básicos que permitan interpretar el desempeño comercial.
#
# Indicadores calculados:
#
# * Ventas totales.
#
# * Producto más vendido.
#
# * Ventas agrupadas por mes.
#
# * Gráfico de evolución temporal de ventas.

# %% [markdown]
# **ORGANIZACIÓN DEL TRABAJO EN JIRA**
#
# Aunque el trabajo es individual, se simulan los roles propuestos en la consigna para respetar la metodología de célula de desarrollo.
#
# Roles asumidos
# * P1 – Líder y Organizador: configuración del repositorio y estructura inicial.
# * P2 – Desarrollador Técnico: desarrollo del script de análisis en Python.
# * P3 – Revisor y QA: revisión de código, documentación y control de seguridad.
#
# Proyecto en Jira
#
# Se creó un proyecto de tipo Software en Jira para organizar las tareas del trabajo práctico.
#
# Issues creados:

# %%
url = "https://github.com/agustinaceliaolmos-boop/Gesti-n-Colaborativa-OE/raw/main/tareas.csv"
df = pd.read_csv(url)
df.head()
# Out:
#        ID Rol                                        Descripción
# 0  PROY-1  P1  Inicialización del repositorio estructura de c...
# 1  PROY-2  P2  Desarrollo del script de análisis de ventas en...
# 2  PROY-3  P3  Revisión de código documentación y validación ...

# %% [markdown]
# **IMPLEMENTACIÓN TÉCNICA (GIT & GITHUB EN GOOGLE COLAB)**
#
# El flujo de trabajo técnico se ejecutó íntegramente desde Google Colab, respetando las restricciones de seguridad del entorno.
#
# **Configuración de seguridad y autenticación**
#
# Para autenticar los pushes al repositorio remoto se utilizó un Personal Access Token (PAT) de tipo Fine-grained, configurado con permisos:
#
# Contents: Read and write
#
# El token no fue expuesto en celdas públicas ni almacenado en el repositorio.

# %% [markdown]
# **Flujo de trabajo con Git**
#
# Inicialización
#
# Creación del repositorio en GitHub.
#
# Clonado del repositorio en Colab:

# %% [markdown]
# **Configuración de identidad en Git**
#
# En una celda de Google Colab se configuró la identidad global:

# %%
# !git config --global user.email "agustina.celia.olmos@mi.unc.edu.ar"
# !git config --global user.name "Agustina celia olmos"

# %% [markdown]
# Esto asegura la correcta autoría de los commits.
